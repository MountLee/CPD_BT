# %% [markdown]
# # Import libraries and setup

# %%
import sys, os, csv, importlib

# %%
import numpy as np
import scipy as sc
import scipy.linalg as spl
import scipy.stats as ss
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import scipy.stats as stats
import random

import itertools

from bt_cpd import *

from datetime import datetime
import time
import bisect

import statsmodels.api as sm
from sklearn import linear_model

from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

# %%
def bt_fit(y, X, lam):
    y = y.reshape((-1,))
    if 0 not in y or 1 not in y:
        return np.zeros((X.shape[1], 1))

    logit = linear_model.LogisticRegression(fit_intercept = False, penalty = 'l2', solver = 'lbfgs',
                                            C = 1/lam, random_state = 0, max_iter = 50)
    logit.fit(X, y)
    beta_hat = logit.coef_
    return beta_hat.reshape((-1,1))

# %%
all_games = pd.read_csv("nba/nba_games.csv")

# %%
len(all_games)
# Out:
# 112808

# %%
all_games.columns
# Out:
# Index(['season', 'game_id', 'team_A_id', 'team_A_city', 'team_A_name',
#        'team_A_pts', 'team_A_fta', 'team_A_ftm', 'team_B_id', 'team_B_city',
#        'team_B_name', 'team_B_pts', 'team_B_fta', 'team_B_ftm'],
#       dtype='object')

# %%
all_games.head()
# Out:
#     season   game_id   team_A_id team_A_city team_A_name  team_A_pts  \
# 0  1949-50  24900558  1610610037    Waterloo       Hawks          79
# 1  1949-50  24900553  1610612737  Tri-Cities  Blackhawks          88
# 2  1949-50  24900529  1610612737  Tri-Cities  Blackhawks          97
# 3  1949-50  24900515  1610612737  Tri-Cities  Blackhawks          67
# 4  1949-50  24900508  1610610023    Anderson     Packers          88
#
#    team_A_fta  team_A_ftm   team_B_id team_B_city team_B_name  team_B_pts  \
# 0        31.0        23.0  1610612737  Tri-Cities  Blackhawks          77
# 1        38.0        28.0  1610612755    Syracuse   Nationals          89
# 2        34.0        23.0  1610610033   Sheboygan    Redskins          79
# 3        38.0        27.0  1610610023    Anderson     Packers          82
# 4        33.0        26.0  1610612737  Tri-Cities  Blackhawks          77
#
#    team_B_fta  team_B_ftm
# 0        27.0        21.0
# 1        33.0        23.0
# 2        36.0        27.0
# 3        43.0        30.0
# 4        22.0        19.0

# %%
len(np.unique(all_games['game_id'].values))
# Out:
# 56430

# %%
all_games[all_games['game_id'] == 24900558]
# Out:
#        season   game_id   team_A_id team_A_city team_A_name  team_A_pts  \
# 0     1949-50  24900558  1610610037    Waterloo       Hawks          79
# 5476  1949-50  24900558  1610610037    Waterloo       Hawks          79
#
#       team_A_fta  team_A_ftm   team_B_id team_B_city team_B_name  team_B_pts  \
# 0           31.0        23.0  1610612737  Tri-Cities  Blackhawks          77
# 5476        31.0        23.0  1610612737  Tri-Cities  Blackhawks          77
#
#       team_B_fta  team_B_ftm
# 0           27.0        21.0
# 5476        27.0        21.0

# %% [markdown]
# Check duplicates

# %%
game_ids = np.unique(all_games['game_id'].values)

# %%
single_id = []
mistake_id = []
more_dup_id = []
for i in game_ids:
    sub = all_games[all_games['game_id'] == i]
    if len(sub) == 1:
        single_id.append(i)
    if len(sub) > 2:
        more_dup_id.append(i)
    if len(sub) == 2:
        pts_1 = (sub['team_A_pts'].values[0],sub['team_B_pts'].values[0])
        pts_2 = (sub['team_A_pts'].values[1],sub['team_B_pts'].values[1])
        if pts_1 != pts_2:
            mistake_id.append(i)

# %%
print(len(single_id))
print(len(mistake_id))
print(len(more_dup_id))
# Out:
# 590
# 0
# 533

# %%
ix = more_dup_id[0]
all_games[all_games['game_id'] == ix]
# Out:
#         season   game_id   team_A_id team_A_city team_A_name  team_A_pts  \
# 11018  2012-13  21201216  1610612761     Toronto     Raptors         114
# 11019  2012-13  21201216  1610612761     Toronto     Raptors         114
# 85078  2012-13  21201216  1610612761     Toronto     Raptors         114
#
#        team_A_fta  team_A_ftm   team_B_id team_B_city team_B_name  team_B_pts  \
# 11018        28.0        22.0  1610612738      Boston     Celtics          90
# 11019        28.0        22.0  1610612738      Boston     Celtics          90
# 85078        28.0        22.0  1610612738      Boston     Celtics          90
#
#        team_B_fta  team_B_ftm
# 11018        13.0         9.0
# 11019        13.0         9.0
# 85078        13.0         9.0

# %%
ix = more_dup_id[0]
all_games[all_games['game_id'] == ix]
# Out:
#         season   game_id   team_A_id team_A_city team_A_name  team_A_pts  \
# 11018  2012-13  21201216  1610612761     Toronto     Raptors         114
# 11019  2012-13  21201216  1610612761     Toronto     Raptors         114
# 85078  2012-13  21201216  1610612761     Toronto     Raptors         114
#
#        team_A_fta  team_A_ftm   team_B_id team_B_city team_B_name  team_B_pts  \
# 11018        28.0        22.0  1610612738      Boston     Celtics          90
# 11019        28.0        22.0  1610612738      Boston     Celtics          90
# 85078        28.0        22.0  1610612738      Boston     Celtics          90
#
#        team_B_fta  team_B_ftm
# 11018        13.0         9.0
# 11019        13.0         9.0
# 85078        13.0         9.0

# %%
year = '2012-13'
all_games[all_games['season'] == year]
# Out:
#          season   game_id   team_A_id   team_A_city team_A_name  team_A_pts  \
# 4980    2012-13  21201218  1610612752      New York      Knicks          98
# 4981    2012-13  21201213  1610612761       Toronto     Raptors         113
# 4982    2012-13  21201179  1610612749     Milwaukee       Bucks         104
# 4983    2012-13  21201164  1610612755  Philadelphia       76ers         101
# 4984    2012-13  21201143  1610612759   San Antonio       Spurs          99
# ...         ...       ...         ...           ...         ...         ...
# 111224  2012-13  21200063  1610612758    Sacramento       Kings         105
# 111225  2012-13  21200048  1610612758    Sacramento       Kings          94
# 111226  2012-13  21200028  1610612758    Sacramento       Kings          98
# 111227  2012-13  21200023  1610612758    Sacramento       Kings          80
# 111228  2012-13  21200007  1610612758    Sacramento       Kings          87
#
#         team_A_fta  team_A_ftm   team_B_id   team_B_city   team_B_name  \
# 4980          16.0        11.0  1610612737       Atlanta         Hawks
# 4981          27.0        23.0  1610612737       Atlanta         Hawks
# 4982          16.0        11.0  1610612737       Atlanta         Hawks
# 4983          22.0        20.0  1610612737       Atlanta         Hawks
# 4984          29.0        24.0  1610612737       Atlanta         Hawks
# ...            ...         ...         ...           ...           ...
# 111224        24.0        18.0  1610612765       Detroit       Pistons
# 111225        23.0        16.0  1610612744  Golden State      Warriors
# 111226        20.0        16.0  1610612754       Indiana        Pacers
# 111227        16.0        13.0  1610612750     Minnesota  Timberwolves
# 111228        16.0        13.0  1610612741       Chicago         Bulls
#
#         team_B_pts  team_B_fta  team_B_ftm
# 4980            92        17.0        16.0
# 4981            96        23.0        17.0
# 4982           109        25.0        17.0
# 4983           124        19.0        18.0
# 4984            97        25.0        22.0
# ...            ...         ...         ...
# 111224         103        31.0        23.0
# 111225          92        28.0        24.0
# 111226         106        27.0        24.0
# 111227          92        36.0        26.0
# 111228          93        33.0        25.0
#
# [2460 rows x 14 columns]

# %%
len(np.unique(all_games[all_games['season'] == year]['game_id'].values))
# Out:
# 1229

# %%
all_games = all_games.drop_duplicates(subset = ['game_id'], keep = 'first', ignore_index = True).reset_index(drop = True)

# %%
all_games
# Out:
#         season   game_id   team_A_id team_A_city   team_A_name  team_A_pts  \
# 0      1949-50  24900558  1610610037    Waterloo         Hawks          79
# 1      1949-50  24900553  1610612737  Tri-Cities    Blackhawks          88
# 2      1949-50  24900529  1610612737  Tri-Cities    Blackhawks          97
# 3      1949-50  24900515  1610612737  Tri-Cities    Blackhawks          67
# 4      1949-50  24900508  1610610023    Anderson       Packers          88
# ...        ...       ...         ...         ...           ...         ...
# 56425  1946-47  24600029  1610610032  Providence  Steamrollers          59
# 56426  1946-47  24600025  1610610035     Toronto       Huskies          85
# 56427  1946-47  24600021  1610610028     Detroit       Falcons          68
# 56428  1946-47  24600019  1610610031  Pittsburgh       Ironmen          84
# 56429  1946-47  24600015  1610610032  Providence  Steamrollers          76
#
#        team_A_fta  team_A_ftm   team_B_id team_B_city   team_B_name  \
# 0            31.0        23.0  1610612737  Tri-Cities    Blackhawks
# 1            38.0        28.0  1610612755    Syracuse     Nationals
# 2            34.0        23.0  1610610033   Sheboygan      Redskins
# 3            38.0        27.0  1610610023    Anderson       Packers
# 4            33.0        26.0  1610612737  Tri-Cities    Blackhawks
# ...           ...         ...         ...         ...           ...
# 56425         NaN        17.0  1610610028     Detroit       Falcons
# 56426        28.0        21.0  1610610032  Providence  Steamrollers
# 56427         NaN        20.0  1610610032  Providence  Steamrollers
# 56428        35.0        26.0  1610610032  Providence  Steamrollers
# 56429         NaN        32.0  1610610031  Pittsburgh       Ironmen
#
#        team_B_pts  team_B_fta  team_B_ftm
# 0              77        27.0        21.0
# 1              89        33.0        23.0
# 2              79        36.0        27.0
# 3              82        43.0        30.0
# 4              77        22.0        19.0
# ...           ...         ...         ...
# 56425          70         NaN        14.0
# 56426          68        34.0        26.0
# 56427          70         NaN        16.0
# 56428          71        42.0        29.0
# 56429          66         NaN        16.0
#
# [56430 rows x 14 columns]

# %%
all_games = all_games.sort_values(by = ['season', 'game_id']).reset_index(drop = True)

# %%
all_games
# Out:
#         season   game_id   team_A_id  team_A_city    team_A_name  team_A_pts  \
# 0      1946-47  24600001  1610610035      Toronto        Huskies          66
# 1      1946-47  24600002  1610610032   Providence   Steamrollers          59
# 2      1946-47  24600003  1610610034    St. Louis        Bombers          56
# 3      1946-47  24600004  1610610025      Chicago          Stags          63
# 4      1946-47  24600005  1610610028      Detroit        Falcons          33
# ...        ...       ...         ...          ...            ...         ...
# 56425  2015-16  21501226  1610612740  New Orleans       Pelicans         109
# 56426  2015-16  21501227  1610612763      Memphis      Grizzlies         104
# 56427  2015-16  21501228  1610612762         Utah           Jazz          96
# 56428  2015-16  21501229  1610612756      Phoenix           Suns         114
# 56429  2015-16  21501230  1610612757     Portland  Trail Blazers         107
#
#        team_A_fta  team_A_ftm   team_B_id   team_B_city   team_B_name  \
# 0            29.0        16.0  1610612752      New York        Knicks
# 1             NaN        17.0  1610612738        Boston       Celtics
# 2             NaN        16.0  1610610031    Pittsburgh       Ironmen
# 3             NaN        21.0  1610612752      New York        Knicks
# 4             NaN        13.0  1610610036    Washington      Capitols
# ...           ...         ...         ...           ...           ...
# 56425        22.0        18.0  1610612750     Minnesota  Timberwolves
# 56426        16.0        12.0  1610612744  Golden State      Warriors
# 56427        15.0         9.0  1610612747   Los Angeles        Lakers
# 56428        22.0        17.0  1610612746            LA      Clippers
# 56429        22.0        18.0  1610612743        Denver       Nuggets
#
#        team_B_pts  team_B_fta  team_B_ftm
# 0              68        26.0        20.0
# 1              53         NaN        11.0
# 2              51         NaN        19.0
# 3              47         NaN        15.0
# 4              50         NaN        14.0
# ...           ...         ...         ...
# 56425         144        23.0        19.0
# 56426         125        16.0        13.0
# 56427         101        15.0        13.0
# 56428         105        12.0        10.0
# 56429          99        18.0        12.0
#
# [56430 rows x 14 columns]

# %%
all_teams = np.unique(np.concatenate([all_games['team_A_name'].values, all_games['team_B_name'].values]))
len(all_teams)
# Out:
# 50

# %%
ix_for_teams = [i for i in range(len(all_games)) if all_games['team_A_name'][i] in all_teams and 
                all_games['team_B_name'][i] in all_teams]

# %%
len(ix_for_teams)
# Out:
# 56430

# %%
team_games = all_games.loc[ix_for_teams,].reset_index(drop = True)[['season', 'game_id','team_A_name',
                                                                   'team_B_name','team_A_pts','team_B_pts']]

# %%
t1 = team_games[['season','team_A_name']].groupby(by = 'team_A_name').agg(['min','max']).reset_index()
t1.columns = ['team', 'min_season', 'max_season']

t2 = team_games[['season','team_B_name']].groupby(by = 'team_B_name').agg(['min','max']).reset_index()
t2.columns = ['team', 'min_season', 'max_season']

all_teams_history = pd.concat([t1,t2]).groupby(by = 'team').min().reset_index()
all_teams_history
# Out:
#              team min_season max_season
# 0           76ers    1963-64    2015-16
# 1      Blackhawks    1949-50    1950-51
# 2         Bobcats    2004-05    2013-14
# 3         Bombers    1946-47    1949-50
# 4          Braves    1970-71    1977-78
# 5           Bucks    1968-69    2015-16
# 6         Bullets    1947-48    1995-96
# 7           Bulls    1966-67    2015-16
# 8        Capitols    1946-47    1950-51
# 9       Cavaliers    1970-71    2015-16
# 10        Celtics    1946-47    2015-16
# 11       Clippers    1978-79    2015-16
# 12        Falcons    1946-47    1946-47
# 13      Grizzlies    1995-96    2015-16
# 14          Hawks    1949-50    1995-96
# 15           Heat    1988-89    2015-16
# 16        Hornets    1988-89    2015-16
# 17        Huskies    1946-47    1946-47
# 18        Ironmen    1946-47    1946-47
# 19           Jazz    1974-75    2015-16
# 20           Jets    1948-49    1948-49
# 21          Kings    1972-73    2015-16
# 22         Knicks    1946-47    2015-16
# 23         Lakers    1948-49    2015-16
# 24          Magic    1989-90    2015-16
# 25      Mavericks    1980-81    2015-16
# 26      Nationals    1949-50    1962-63
# 27           Nets    1976-77    2015-16
# 28        Nuggets    1949-50    2015-16
# 29      Olympians    1949-50    1952-53
# 30         Pacers    1976-77    2015-16
# 31        Packers    1949-50    1961-62
# 32       Pelicans    2013-14    2015-16
# 33        Pistons    1948-49    2015-16
# 34        Raptors    1995-96    2015-16
# 35         Rebels    1946-47    1946-47
# 36       Redskins    1949-50    1949-50
# 37        Rockets    1967-68    2015-16
# 38         Royals    1948-49    1971-72
# 39          Spurs    1976-77    2015-16
# 40          Stags    1946-47    1949-50
# 41   Steamrollers    1946-47    1948-49
# 42           Suns    1968-69    2015-16
# 43    SuperSonics    1967-68    2007-08
# 44        Thunder    2008-09    2015-16
# 45   Timberwolves    1989-90    2015-16
# 46  Trail Blazers    1970-71    2015-16
# 47       Warriors    1946-47    2015-16
# 48        Wizards    1997-98    2015-16
# 49        Zephyrs    1962-63    1962-63

# %%
teams_ix = np.where(np.logical_and(all_teams_history['min_season'].values < '1990', 
                                   all_teams_history['max_season'].values > '2014'))[0]
print(len(teams_ix))
teams = all_teams_history['team'].values[teams_ix]
rm = []
teams = [t for t in teams if t not in rm]
print(len(teams))
teams
# Out:
# 24
# 24
# ['76ers',
#  'Bucks',
#  'Bulls',
#  'Cavaliers',
#  'Celtics',
#  'Clippers',
#  'Heat',
#  'Hornets',
#  'Jazz',
#  'Kings',
#  'Knicks',
#  'Lakers',
#  'Magic',
#  'Mavericks',
#  'Nets',
#  'Nuggets',
#  'Pacers',
#  'Pistons',
#  'Rockets',
#  'Spurs',
#  'Suns',
#  'Timberwolves',
#  'Trail Blazers',
#  'Warriors']

# %%
ix_for_teams = [i for i in range(len(all_games)) if all_games['team_A_name'][i] in teams and 
                all_games['team_B_name'][i] in teams]

# %%
len(ix_for_teams)
# Out:
# 35423

# %%
ix_team_time = [i for i in range(len(all_games)) if all_games['team_A_name'][i] in teams and 
                all_games['team_B_name'][i] in teams and all_games['season'][i] > '1980']
len(ix_team_time)
# Out:
# 27736

# %%
games = all_games.iloc[ix_team_time].reset_index(drop = True)[['season', 'game_id','team_A_name',
                                                                   'team_B_name','team_A_pts','team_B_pts']]

# %%
len(games)
# Out:
# 27736

# %%
games
# Out:
#         season   game_id    team_A_name    team_B_name  team_A_pts  team_B_pts
# 0      1980-81  28000001           Suns       Warriors         121         101
# 1      1980-81  28000002        Nuggets          Spurs         112         113
# 2      1980-81  28000003          76ers          Bucks         103         106
# 3      1980-81  28000004       Clippers        Rockets         120         104
# 4      1980-81  28000008           Jazz  Trail Blazers          96          86
# ...        ...       ...            ...            ...         ...         ...
# 27731  2015-16  21501224          Kings        Rockets          81         116
# 27732  2015-16  21501225          Bucks         Pacers          92          97
# 27733  2015-16  21501228           Jazz         Lakers          96         101
# 27734  2015-16  21501229           Suns       Clippers         114         105
# 27735  2015-16  21501230  Trail Blazers        Nuggets         107          99
#
# [27736 rows x 6 columns]

# %%
t1 = games[['season','team_A_name']].groupby(by = 'team_A_name').agg(['min','max']).reset_index()
t1.columns = ['team', 'min_season', 'max_season']

t2 = games[['season','team_B_name']].groupby(by = 'team_B_name').agg(['min','max']).reset_index()
t2.columns = ['team', 'min_season', 'max_season']

teams_history = pd.concat([t1,t2]).groupby(by = 'team').min().reset_index()
teams_history
# Out:
#              team min_season max_season
# 0           76ers    1980-81    2015-16
# 1           Bucks    1980-81    2015-16
# 2           Bulls    1980-81    2015-16
# 3       Cavaliers    1980-81    2015-16
# 4         Celtics    1980-81    2015-16
# 5        Clippers    1980-81    2015-16
# 6            Heat    1988-89    2015-16
# 7         Hornets    1988-89    2015-16
# 8            Jazz    1980-81    1995-96
# 9           Kings    1980-81    2015-16
# 10         Knicks    1980-81    2015-16
# 11         Lakers    1980-81    2015-16
# 12          Magic    1989-90    2015-16
# 13      Mavericks    1980-81    2015-16
# 14           Nets    1980-81    2011-12
# 15        Nuggets    1980-81    2015-16
# 16         Pacers    1980-81    2015-16
# 17        Pistons    1980-81    2015-16
# 18        Rockets    1980-81    2015-16
# 19          Spurs    1980-81    2015-16
# 20           Suns    1980-81    2015-16
# 21   Timberwolves    1989-90    2015-16
# 22  Trail Blazers    1980-81    2015-16
# 23       Warriors    1980-81    2015-16

# %%
teams = teams_history['team'].values

# %%
team_to_id = {teams[i]:i for i in range(len(teams))}
print(len(teams))
# Out:
# 24

# %%
T = len(games)
p = len(teams)
X = np.zeros((T,p))
Y = np.zeros(T)
for i in range(T):
    cur = games.loc[i,]
    t = [team_to_id[cur['team_A_name']],team_to_id[cur['team_B_name']]]
    t1, t2 = t
    X[i, t1] = 1
    X[i, t2] = -1
    if cur['team_A_pts'] > cur['team_B_pts']:
        Y[i] = 1
    else:
        Y[i] = 0

# %%
lam = 0.1
beta_all = bt_fit(Y, X, lam).reshape((-1,))

# %%
score_all = pd.DataFrame({'team':teams, 'theta_all':beta_all}).sort_values(by = 'theta_all', ascending=False)
score_all
# Out:
#              team  theta_all
# 11         Lakers   0.520348
# 19          Spurs   0.500588
# 8            Jazz   0.268228
# 22  Trail Blazers   0.257066
# 20           Suns   0.247791
# 18        Rockets   0.199145
# 4         Celtics   0.195587
# 2           Bulls   0.082627
# 17        Pistons   0.038917
# 13      Mavericks   0.033090
# 6            Heat  -0.006096
# 16         Pacers  -0.026809
# 12          Magic  -0.074057
# 15        Nuggets  -0.089604
# 1           Bucks  -0.091782
# 10         Knicks  -0.102242
# 7         Hornets  -0.112855
# 0           76ers  -0.123739
# 3       Cavaliers  -0.124840
# 23       Warriors  -0.189177
# 9           Kings  -0.270430
# 14           Nets  -0.323193
# 5        Clippers  -0.403166
# 21   Timberwolves  -0.405398

# %% [markdown]
# ## Fit BTL for each season and check the path

# %%
all_seasons = np.unique(games['season'].values)
all_seasons
# Out:
# array(['1980-81', '1981-82', '1982-83', '1983-84', '1984-85', '1985-86',
#        '1986-87', '1987-88', '1988-89', '1989-90', '1990-91', '1991-92',
#        '1992-93', '1993-94', '1994-95', '1995-96', '1996-97', '1997-98',
#        '1998-99', '1999-00', '2000-01', '2001-02', '2002-03', '2003-04',
#        '2004-05', '2005-06', '2006-07', '2007-08', '2008-09', '2009-10',
#        '2010-11', '2011-12', '2012-13', '2013-14', '2014-15', '2015-16'],
#       dtype=object)

# %%
n = len(teams)
T = len(all_seasons)
beta_season = np.zeros((T, n))

lam = 0.1
for i, s in enumerate(all_seasons):
    ix = np.where(games['season'].values == s)[0]
    print(s + ': ' + str(len(ix)))
    Y_cur = Y[ix]
    X_cur = X[ix]
    beta_cur = bt_fit(Y_cur, X_cur, lam).reshape((-1,))
    beta_season[i] = beta_cur.copy()
# Out:
# 1980-81: 705
# 1981-82: 706
# 1982-83: 707
# 1983-84: 707
# 1984-85: 707
# 1985-86: 706
# 1986-87: 706
# 1987-88: 707
# 1988-89: 787
# 1989-90: 869
# 1990-91: 869
# 1991-92: 869
# 1992-93: 869
# 1993-94: 869
# 1994-95: 869
# 1995-96: 807
# 1996-97: 806
# 1997-98: 806
# 1998-99: 491
# 1999-00: 807
# 2000-01: 807
# 2001-02: 805
# 2002-03: 807
# 2003-04: 807
# 2004-05: 779
# 2005-06: 781
# 2006-07: 780
# 2007-08: 781
# 2008-09: 781
# 2009-10: 779
# 2010-11: 781
# 2011-12: 629
# 2012-13: 779
# 2013-14: 714
# 2014-15: 779
# 2015-16: 778

# %%
beta_path = beta_season.copy()

# %%
T, n = beta_path.shape
year = np.arange(1980,2015 + 1)
f = plt.figure(1, figsize = (12,6))

for i in range(n):
    plt.plot(year, beta_path[:,i], label=teams[i], color = np.random.rand(3,))
plt.xlabel("year")
plt.ylabel("theta")
plt.ticklabel_format(style='plain',axis='x',useOffset=False)

#get handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
#specify order of items in legend
order = np.argsort(-beta_path[-1])
#add legend to plot
plt.legend([handles[idx] for idx in order],[labels[idx] for idx in order],
          loc='center left',bbox_to_anchor=(1, 0, 0, 1),prop={'size': 9}) 
# plt.legend(loc='center left', bbox_to_anchor=(1, 1, 1, 0),prop={'size': 11.3})
plt.savefig('theta_path_2.pdf', bbox_inches='tight')

# %% [markdown]
# # CPD by WBS

# %%
T = len(Y)
X_train, Y_train = X[0:T:2], Y[0:T:2]
X_test, Y_test = X[1:T:2], Y[1:T:2]

# %% [markdown]
# ### Standard tuning

# %%
np.random.seed(0)

m_intervals = 50
grid_n = 100
gamma_list = [60, 80, 100]
lam_list = [0.1]

start_time = time.time()
wbs_fit = wbs_cv_bt(m_intervals, grid_n, lam_list, gamma_list, smooth = 5, buffer = 5)
res = wbs_fit.fit((X_train, Y_train), (X_test, Y_test))
cp_best, cp_val, cusum_val, gamma_best, fit_best = res   
run_time_wbs = time.time() - start_time
K_wbs = len(cp_best)

print("cp: {0}".format(sorted(cp_best)))
print("got: {0}".format(fit_best))
print("gamma: {0}".format(gamma_best))
print("avg time: {0}".format(run_time_wbs))
# Out:
# cp: [3864, 7314, 10350, 12282]
# got: 1796.916700212904
# gamma: 80
# avg time: 82.88640594482422

# %%
np.random.seed(0)

m_intervals = 100
grid_n = 100
gamma_list = [60, 80, 100]
lam_list = [0.1]

start_time = time.time()
wbs_fit = wbs_cv_bt(m_intervals, grid_n, lam_list, gamma_list, smooth = 5, buffer = 5)
res = wbs_fit.fit((X_train, Y_train), (X_test, Y_test))
cp_best, cp_val, cusum_val, gamma_best, fit_best = res   
run_time_wbs = time.time() - start_time
K_wbs = len(cp_best)

print("cp: {0}".format(sorted(cp_best)))
print("got: {0}".format(fit_best))
print("gamma: {0}".format(gamma_best))
print("avg time: {0}".format(run_time_wbs))
# Out:
# cp: [3864, 7314, 10350, 12282]
# got: 1796.916700212904
# gamma: 80
# avg time: 174.09668922424316

# %%
np.random.seed(0)

m_intervals = 150
grid_n = 100
gamma_list = [60, 80, 100]
lam_list = [0.1]

start_time = time.time()
wbs_fit = wbs_cv_bt(m_intervals, grid_n, lam_list, gamma_list, smooth = 5, buffer = 5)
res = wbs_fit.fit((X_train, Y_train), (X_test, Y_test))
cp_best, cp_val, cusum_val, gamma_best, fit_best = res   
run_time_wbs = time.time() - start_time
K_wbs = len(cp_best)

print("cp: {0}".format(sorted(cp_best)))
print("got: {0}".format(fit_best))
print("gamma: {0}".format(gamma_best))
print("avg time: {0}".format(run_time_wbs))
# Out:
# cp: [3864, 7314, 10350, 12282]
# got: 1796.916700212904
# gamma: 80
# avg time: 249.81458616256714

# %%
np.random.seed(0)

m_intervals = 200
grid_n = 100
gamma_list = [60, 80, 100]
lam_list = [0.1]

start_time = time.time()
wbs_fit = wbs_cv_bt(m_intervals, grid_n, lam_list, gamma_list, smooth = 5, buffer = 5)
res = wbs_fit.fit((X_train, Y_train), (X_test, Y_test))
cp_best, cp_val, cusum_val, gamma_best, fit_best = res   
run_time_wbs = time.time() - start_time
K_wbs = len(cp_best)

print("cp: {0}".format(sorted(cp_best)))
print("got: {0}".format(fit_best))
print("gamma: {0}".format(gamma_best))
print("avg time: {0}".format(run_time_wbs))
# Out:
# cp: [3864, 7176, 10350, 12282]
# got: 1793.2404133969878
# gamma: 80
# avg time: 300.3340151309967

# %%
np.random.seed(0)

m_intervals = 250
grid_n = 100
gamma_list = [60, 80, 100]
lam_list = [0.1]

start_time = time.time()
wbs_fit = wbs_cv_bt(m_intervals, grid_n, lam_list, gamma_list, smooth = 5, buffer = 5)
res = wbs_fit.fit((X_train, Y_train), (X_test, Y_test))
cp_best, cp_val, cusum_val, gamma_best, fit_best = res   
run_time_wbs = time.time() - start_time
K_wbs = len(cp_best)

print("cp: {0}".format(sorted(cp_best)))
print("got: {0}".format(fit_best))
print("gamma: {0}".format(gamma_best))
print("avg time: {0}".format(run_time_wbs))
# Out:
# cp: [3864, 7314, 10350, 12282]
# got: 1796.916700212904
# gamma: 80
# avg time: 410.9364035129547

# %% [markdown]
# Check seasons of change points

# %%
cp = [3864, 7176, 10350, 12282]
cp.sort()
cp = [x * 2 for x in cp]
cp = [0] + cp + [len(games) - 1]

print(cp)
games.iloc[cp]
# Out:
# [0, 7728, 14352, 20700, 24564, 27735]
#         season   game_id    team_A_name team_B_name  team_A_pts  team_B_pts
# 0      1980-81  28000001           Suns    Warriors         121         101
# 7728   1990-91  29000534        Hornets      Lakers          93         113
# 14352  1998-99  29800414          Kings     Rockets          93         107
# 20700  2006-07  20600871         Knicks    Warriors         106          97
# 24564  2011-12  21100798           Nets      Lakers          87          91
# 27735  2015-16  21501230  Trail Blazers     Nuggets         107          99

# %%
games_ = games[['season']]
games_['index'] = games.index
games_.groupby(['season']).first()
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          index
# season
# 1980-81      0
# 1981-82    705
# 1982-83   1411
# 1983-84   2118
# 1984-85   2825
# 1985-86   3532
# 1986-87   4238
# 1987-88   4944
# 1988-89   5651
# 1989-90   6438
# 1990-91   7307
# 1991-92   8176
# 1992-93   9045
# 1993-94   9914
# 1994-95  10783
# 1995-96  11652
# 1996-97  12459
# 1997-98  13265
# 1998-99  14071
# 1999-00  14562
# 2000-01  15369
# 2001-02  16176
# 2002-03  16981
# 2003-04  17788
# 2004-05  18595
# 2005-06  19374
# 2006-07  20155
# 2007-08  20935
# 2008-09  21716
# 2009-10  22497
# 2010-11  23276
# 2011-12  24057
# 2012-13  24686
# 2013-14  25465
# 2014-15  26179
# 2015-16  26958

# %% [markdown]
# Fit the BTL model on each cp interval

# %%
def fit_bt_with_cp(cp):
    K = len(cp) - 1
    p = X.shape[1]
    beta_path = np.zeros((K, p))
    lam = 0.1

    for i in range(K):
        X_cur = X[cp[i]:cp[i + 1]]
        Y_cur = Y[cp[i]:cp[i + 1]]
    
        beta_cur = bt_fit(Y_cur, X_cur, lam).reshape((-1,))
        beta_path[i] = beta_cur.copy()    

    score_all = pd.DataFrame({'team':teams, 'theta_all':np.round(beta_all, 4)}).sort_values(by = 'theta_all', ascending=False, ignore_index=True)

    for i in range(K):
        score_cur = pd.DataFrame({('team_' + str(i)):teams, ('theta_' + str(i)):np.round(beta_path[i], 4)}).sort_values(by = 'theta_' + str(i), ascending=False, ignore_index=True)
        score_all = pd.concat([score_all, score_cur], axis = 1)
    return score_all

# %%
score_all = fit_bt_with_cp(cp)
score_all
# Out:
#              team  theta_all         team_0  theta_0         team_1  theta_1  \
# 0          Lakers     0.5203        Celtics   1.1137          Bulls   0.9435
# 1           Spurs     0.5006         Lakers   1.0840           Jazz   0.7996
# 2            Jazz     0.2682          76ers   0.8049           Suns   0.5405
# 3   Trail Blazers     0.2571          Bucks   0.7336         Knicks   0.5178
# 4            Suns     0.2478        Pistons   0.5074        Rockets   0.5080
# 5         Rockets     0.1991  Trail Blazers   0.4466  Trail Blazers   0.4931
# 6         Celtics     0.1956           Suns   0.2840          Spurs   0.4638
# 7           Bulls     0.0826        Nuggets   0.2294      Cavaliers   0.3415
# 8         Pistons     0.0389          Bulls   0.1782         Lakers   0.3338
# 9       Mavericks     0.0331           Jazz   0.1774         Pacers   0.2410
# 10           Heat    -0.0061          Spurs   0.1394          Magic   0.1824
# 11         Pacers    -0.0268        Rockets   0.1252        Hornets   0.0923
# 12          Magic    -0.0741      Mavericks   0.1004           Heat   0.0572
# 13        Nuggets    -0.0896         Knicks   0.0744        Pistons  -0.1381
# 14          Bucks    -0.0918       Warriors  -0.1406       Warriors  -0.2101
# 15         Knicks    -0.1022           Nets  -0.1751        Celtics  -0.2326
# 16        Hornets    -0.1129         Pacers  -0.1857           Nets  -0.3088
# 17          76ers    -0.1237      Cavaliers  -0.2179          Bucks  -0.4730
# 18      Cavaliers    -0.1248          Kings  -0.3197       Clippers  -0.5024
# 19       Warriors    -0.1892       Clippers  -0.6276          Kings  -0.5103
# 20          Kings    -0.2704   Timberwolves  -0.9485        Nuggets  -0.6578
# 21           Nets    -0.3232        Hornets  -1.0599   Timberwolves  -0.6859
# 22       Clippers    -0.4032          Magic  -1.1178          76ers  -0.7395
# 23   Timberwolves    -0.4054           Heat  -1.2060      Mavericks  -1.0560
#
#            team_2  theta_2         team_3  theta_3         team_4  theta_4
# 0           Spurs   0.9040         Lakers   0.7579          Spurs   1.1659
# 1       Mavericks   0.6650          Spurs   0.7010       Clippers   0.9448
# 2          Lakers   0.5904        Celtics   0.6406       Warriors   0.9106
# 3           Kings   0.5103          Magic   0.6084           Heat   0.5149
# 4            Suns   0.3677      Mavericks   0.6050        Rockets   0.4703
# 5    Timberwolves   0.2767        Nuggets   0.4580      Mavericks   0.3402
# 6         Pistons   0.2464          Bulls   0.2974         Pacers   0.3368
# 7            Jazz   0.2266           Suns   0.2800  Trail Blazers   0.2782
# 8          Pacers   0.1902        Rockets   0.2724          Bulls   0.2639
# 9         Rockets   0.0024           Jazz   0.2499        Nuggets   0.0401
# 10  Trail Blazers  -0.0049  Trail Blazers   0.1843           Jazz  -0.0495
# 11           Heat  -0.0433      Cavaliers   0.1628      Cavaliers  -0.0752
# 12          76ers  -0.0673        Hornets   0.0931        Celtics  -0.1486
# 13           Nets  -0.0807           Heat   0.0810        Hornets  -0.1522
# 14        Hornets  -0.1130          76ers  -0.1570           Nets  -0.2055
# 15          Bucks  -0.2183        Pistons  -0.2651         Knicks  -0.2865
# 16        Nuggets  -0.2676       Warriors  -0.3028           Suns  -0.2960
# 17          Magic  -0.2993         Pacers  -0.3475          Bucks  -0.3540
# 18         Knicks  -0.3218          Bucks  -0.4778        Pistons  -0.3591
# 19        Celtics  -0.3293         Knicks  -0.6236          Kings  -0.4707
# 20       Clippers  -0.4028       Clippers  -0.6919         Lakers  -0.5136
# 21      Cavaliers  -0.4321          Kings  -0.7288   Timberwolves  -0.5649
# 22       Warriors  -0.5857   Timberwolves  -0.8974          Magic  -0.6970
# 23          Bulls  -0.8137           Nets  -0.8998          76ers  -1.0930
